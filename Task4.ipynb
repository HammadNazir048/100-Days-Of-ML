# %%
print ("Hello Word!")
# Out:
# Hello Word!

# %%
print (1 + 2)
# Out:
# 3

# %%
print (9 + 5)
# Out:
# 14

# %%
print(((1 + 3) * (9 - 2) / 2) ** 2)
# Out:
# 196.0

# %%
print(3 * 2)
# Out:
# 6

# %%
print (3 / 2)
# Out:
# 1.5

# %%
test_var = 4 + 5

print(test_var)
# Out:
# 9

# %%
my_var = 3

print(my_var)

my_var = 100

print(my_var)
# Out:
# 3
# 100

# %%
print(my_var)
print(test_var)
# Out:
# 100
# 9

# %%
my_var = my_var + 3

print(my_var)
# Out:
# 103

# %%
num_years = 4
days_per_year = 365 
hours_per_day = 24
mins_per_hour = 60
secs_per_min = 60

total_secs = secs_per_min * mins_per_hour * hours_per_day * days_per_year * num_years
print(total_secs)
# Out:
# 126144000

# %%
days_per_year = 365.25

total_secs = secs_per_min * mins_per_hour * hours_per_day * days_per_year * num_years
print(total_secs)
# Out:
# 126230400.0

# %%
hours_per_day = 24

total_secs = secs_per_min * mins_per_hour * hours_per_day 
print (total_secs)
# Out:
# 86400
